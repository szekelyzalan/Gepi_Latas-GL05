# %%
# !git clone https://github.com/szekelyzalan/Gepi_Latas-GL05.git
# Out:
# Cloning into 'Gepi_Latas-GL05'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 59 (delta 18), reused 24 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (59/59), 828.92 KiB | 3.36 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
# %cd Gepi_Latas-GL05/
# Out:
# /content/Gepi_Latas-GL05

# %%
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...

# %%
# !pip3 install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/train.zip -d /content/Gepi_Latas-GL05/
# Out:
# Archive:  /content/drive/MyDrive/train.zip
# replace /content/Gepi_Latas-GL05/train/--L1OMr84-e5nOLbNH5sBA.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/Gepi_Latas-GL05/train/--L1OMr84-e5nOLbNH5sBA.jpg
#   inflating: /content/Gepi_Latas-GL05/train/-beRiLdyaEnBx7oBtGsRwA.jpg
#   inflating: /content/Gepi_Latas-GL05/train/-BFA9HVpWeUoZDREdSQ7Eg.jpg
#   inflating: /content/Gepi_Latas-GL05/train/-c9SuzQwP_tsh0f9Lg5YdA.jpg
#   inflating: /content/Gepi_Latas-GL05/train/-FoGtcpcd4cf0EgwoJmgow.jpg
#   inflating: /content/Gepi_Latas-GL05/train/-GcyRUxSLj-AxfnjeWRtWg.jpg
#   inflating: /content/Gepi_Latas-GL05/train/-ICAhB_M1FXslMMVcAjf_A.jpg
#   inflating: /content/Gepi_Latas-GL05/train/-NQmKWfAuPWZt3s7WrwAuQ.jpg
#   inflating: /content/Gepi_Latas-GL05/train/-NwNtJhFViGM59D_ir2HRg.jpg
#   inflating: /content/Gepi_Latas-GL05/train/-OFnZf4-3iLhJVoE3xhs7g.jpg
#   inflating: /content/Gepi_Latas-GL05/train/-OG52dnk6NNuOkNxA-H3jQ.jpg
# ...

# %%
# !python src/split_data.py
# Out:
# {'speed_limit': 0, 'pedestrian_crossing': 1, 'yield': 2, 'no_entry': 3, 'stop': 4}
#
# Használt képek: 403
#
# Split stat:
# train: 282 képek (target: 282)
# val: 80 képek (target: 80)
# test: 41 képek (target: 41)
#
# Class distribution:
#
# speed_limit:
#   train: 0.458
#   val: 0.125
#   test: 0.074
#
# pedestrian_crossing:
#   train: 0.542
#   val: 0.164
#   test: 0.073
#
# yield:
#   train: 0.613
#   val: 0.169
#   test: 0.092
#
# no_entry:
#   train: 0.625
#   val: 0.167
#   test: 0.069
#
# stop:
#   train: 0.600
#   val: 0.200
#   test: 0.091

# %%
# !python src/split_inspector.py
# Out:
# 0:
# 	train: 0.8842592592592593
# 	val: 0.25462962962962965
# 	test: 0.2175925925925926
# 1:
# 	train: 0.7853107344632768
# 	val: 0.2824858757062147
# 	test: 0.15819209039548024
# 2:
# 	train: 0.8380281690140845
# 	val: 0.28169014084507044
# 	test: 0.16901408450704225
# 3:
# 	train: 0.7916666666666666
# 	val: 0.2638888888888889
# 	test: 0.1111111111111111
# 4:
# 	train: 0.8545454545454545
# 	val: 0.23636363636363636
# 	test: 0.14545454545454545

# %%
"""
Example code for training a YOLO network.
"""

from ultralytics import YOLO

def train_yolo():
    """
    Model settings and training.
    """
    model = YOLO("yolov8s.pt")
    results = model.train(
        data="yolo_dataset/data.yaml",
        epochs=100,
        imgsz=1000,
        batch=16,
        patience=20,

        optimizer="SGD",
        lr0=0.01,
        lrf=0.01,
        weight_decay=0.0005,

        hsv_h=0.015,
        hsv_s=0.7,
        hsv_v=0.4,

        degrees=5,
        translate=0.1,
        scale=0.5,
        shear=2.0,
        perspective=0.0005,

        fliplr=0.5,
        flipud=0.0,

        mosaic=1.0,
        mixup=0.1,

        device=0, # If there is GPU -> 0
        workers=4,
        project="runs/detect",
        name="traffic_signs",
        exist_ok=True
    )

    print("Training finished.")
    print(results)


if __name__ == "__main__":
    train_yolo()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
